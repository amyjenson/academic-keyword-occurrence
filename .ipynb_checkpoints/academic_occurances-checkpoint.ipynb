# %%
# Academic word occurance
# if ran too many times in one day, then need to wait a day (or some hours) until you can access Google Scholar again

# %%
# !python extract_occurrences.py 'glaciers' 1976 2024
# eventually !python extract_occurrences.py 'glaciers' and 'sea level rise glaciers' 1940 1950
# Out:
# year,results
# 1950,318
# 1951,376
# 1952,355
# 1953,394
# 1954,404
# 1955,438
# 1956,479
# 1957,491
# 1958,492
# 1959,586
# 1960,596
# 1961,562
# 1962,617
# 1963,725
# 1964,769
# 1965,809
# 1966,801
# 1967,866
# 1968,950
# 1969,1080
# 1970,1080
# 1971,1160
# 1972,1250
# 1973,1260
# 1974,1160
# 1975,1220
# 1976,1400
# 1977,1430
# 1978,1580
# 1979,1690
# 1980,1790
# 1981,1580
# 1982,1760
# 1983,1840
# 1984,1990
# 1985,1780
# 1986,2110
# 1987,2330
# 1988,2450
# 1989,2550
# 1990,3010
# 1991,3070
# 1992,3360
# 1993,3360
# 1994,3580
# Traceback (most recent call last):
#   File "/Users/amyjenson/Documents/GitHub/academic-keyword-occurrence/extract_occurrences.py", line 75, in <module>
#     html = get_range(search_term, start_date, end_date)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/amyjenson/Documents/GitHub/academic-keyword-occurrence/extract_occurrences.py", line 51, in get_range
#     num_results, success = get_num_results(search_term, date, date)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/amyjenson/Documents/GitHub/academic-keyword-occurrence/extract_occurrences.py", line 19, in get_num_results
#     handler = opener.open(request)
#               ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/amyjenson/miniconda3/envs/pseudo_base/lib/python3.12/urllib/request.py", line 521, in open
#     response = meth(req, response)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/Users/amyjenson/miniconda3/envs/pseudo_base/lib/python3.12/urllib/request.py", line 630, in http_response
#     response = self.parent.error(
#                ^^^^^^^^^^^^^^^^^^
#   File "/Users/amyjenson/miniconda3/envs/pseudo_base/lib/python3.12/urllib/request.py", line 553, in error
#     result = self._call_chain(*args)
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/amyjenson/miniconda3/envs/pseudo_base/lib/python3.12/urllib/request.py", line 492, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/Users/amyjenson/miniconda3/envs/pseudo_base/lib/python3.12/urllib/request.py", line 745, in http_error_302
#     return self.parent.open(new, timeout=req.timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/amyjenson/miniconda3/envs/pseudo_base/lib/python3.12/urllib/request.py", line 521, in open
#     response = meth(req, response)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/Users/amyjenson/miniconda3/envs/pseudo_base/lib/python3.12/urllib/request.py", line 630, in http_response
#     response = self.parent.error(
#                ^^^^^^^^^^^^^^^^^^
#   File "/Users/amyjenson/miniconda3/envs/pseudo_base/lib/python3.12/urllib/request.py", line 559, in error
#     return self._call_chain(*args)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/amyjenson/miniconda3/envs/pseudo_base/lib/python3.12/urllib/request.py", line 492, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/Users/amyjenson/miniconda3/envs/pseudo_base/lib/python3.12/urllib/request.py", line 639, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 429: Too Many Requests

# %%
import matplotlib.pyplot as plt
import os
import pandas as pd

data_path = '/Users/amyjenson/Documents/GitHub/academic-keyword-occurrence/'

data_fn1 = os.path.join(data_path, 'sea_level_rise_glaciers_1950-1994.csv')
data1 = pd.read_csv(data_fn1)
data_fn2 = os.path.join(data_path, 'sea_level_rise_glaciers_1995-2009.csv')
data2 = pd.read_csv(data_fn2)
data_fn3 = os.path.join(data_path, 'sea_level_rise_glaciers_2010-2020.csv')
data3 = pd.read_csv(data_fn3)
data_fn4 = os.path.join(data_path, 'sea_level_rise_glaciers_2021-2024.csv')
data4 = pd.read_csv(data_fn4)

SLR_glaciers_data = pd.concat([data1, data2, data3, data4], ignore_index=True)

data_fn1 = os.path.join(data_path, 'glaciers_1950-1975.csv')
data1 = pd.read_csv(data_fn1)
# data_fn2 = os.path.join(data_path, 'glaciers_2010-2020.csv')
# data2 = pd.read_csv(data_fn2)
glaciers_data = pd.concat([data1], ignore_index=True)

#print(SLR_glaciers_data)
#print(glaciers_data)

SLR_glaciers_year = SLR_glaciers_data['year']
SLR_glaciers_results = SLR_glaciers_data['results']
glaciers_year = glaciers_data['year']
glaciers_results = glaciers_data['results']

plt.plot(SLR_glaciers_year, SLR_glaciers_results)
plt.plot(glaciers_year, glaciers_results)
plt.ylabel('Occurences in academic papers')
plt.xlabel('Date')
plt.legend(['sea level rise glaciers', 'glaciers'])
plt.savefig('occurrences.png')
plt.show()

# %%
# percentage of total papers published

plt.plot(SLR_glaciers_year, SLR_glaciers_results/glaciers_results)
plt.title('Percentage of total papers published with the word glaciers')
plt.ylabel('Percentage %')
plt.xlabel('Date')
plt.legend(['sea level rise glaciers', 'glaciers'])
plt.savefig('occurrences.png')
plt.show()
